# %% [markdown]
# ### Input File extraction and XSLT transformation with lxml

# %%
from lxml import etree as et
from pathlib import Path

input_doc = Path.cwd() / 'files' / 'schema' / 'input' / 'AccountAttributes.xsd'
with open(input_doc, 'r') as input_file:
    schema = et.parse(input_file)

xslt_doc =  Path.cwd() / 'files' / 'common' / 'xslt_doc.xml'
with open(xslt_doc, 'r') as xslt_file:
    xslt = et.XSLT(et.parse(xslt_file))

transformed_data = xslt(schema)

transformed_doc = Path.cwd() / 'files' / 'schema' / 'generated' / 'transformed_doc.xml'
transformed_data.write(transformed_doc)
